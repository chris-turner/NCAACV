# %%
# %pip install ultralytics
# %pip install roboflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: C:\Users\Chris\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ------------- -------------------------- 13.1/38.8 MB 68.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.3/38.8 MB 69.2 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.8 MB 70.0 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 61.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 34.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 9.9/9.9 MB 55.8 MB/s eta 0:00:00
# ...
#
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="QYqja6QiWgNXkoRTGPZR")
project = rf.workspace("nflfootball").project("football-generic-player-tracker-rkcmz")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Generic-Player-Tracker-2 in yolov5pytorch:: 100%|██████████| 3318/3318 [00:03<00:00, 954.14it/s]

# %%
import shutil
shutil.move('Football-Generic-Player-Tracker-2/train',
            'Football-Generic-Player-Tracker-2/Football-Generic-Player-Tracker-2/train'
            )

shutil.move('Football-Generic-Player-Tracker-2/test',
            'Football-Generic-Player-Tracker-2/Football-Generic-Player-Tracker-2/test'
            )

shutil.move('Football-Generic-Player-Tracker-2/valid',
            'Football-Generic-Player-Tracker-2/Football-Generic-Player-Tracker-2/valid'
            )
# Out:
# 'Football-Generic-Player-Tracker-2/football-players-detection-1/valid'

# %%
# !yolo task=detect mode=train model=yolov5s.pt data=Football-Generic-Player-Tracker-2/data.yaml epochs=100 imgsz=640
